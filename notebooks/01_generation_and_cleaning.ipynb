# %% [markdown]
# ## 1. Load the raw synthetic fraud CSV
#
# After generating the dataset using ChatGPT, we:
#
# 1. Copied the CSV output into a file named
#    `synthetic_fraud_dataset.csv`.
# 2. Placed it inside the `data/` folder of our project.
#
# In this step, we use `pandas.read_csv` to load the dataset and inspect
# its basic structure (shape and first few rows).

# %%
import pandas as pd

# Path to the CSV generated from ChatGPT output
raw_path = "../data/raw/synthetic_fraud_dataset.csv"

# Read the CSV into a pandas DataFrame
df_raw = pd.read_csv(raw_path)

# Show basic information about size and preview of the data
print("Raw shape (rows, columns):", df_raw.shape)
df_raw.head()
# Out:
# Raw shape (rows, columns): (1200, 12)
#    transaction_id  customer_id transaction_datetime country       channel  \
# 0               1         1119  2022-04-21T21:41:41      AU    mobile_app
# 1               2         1166  2022-01-31T02:59:48      JP           web
# 2               3         1142  2024-09-23T04:12:18      CN           web
# 3               4         1060  2024-04-06T03:56:36      SG  pos_terminal
# 4               5         1018  2022-01-20T14:39:36      US  pos_terminal
#
#   merchant_category   amount  device_trust_score  num_txn_24h_customer  \
# 0            gaming   547.24                78.0                     3
# 1            luxury  1069.52                17.0                     0
# 2            travel   305.73                16.0                     4
# 3       electronics  2096.71                76.0                     2
# 4         groceries   663.15                18.0                     2
#
#    previous_chargeback_count  is_fraud     transaction_note
# 0                          3         0        VPN suspected
# 1                          2         0   overnight shipping
# 2                          1         0                  NaN
# 3                          2         0      high value item
# 4                          3         0  first time merchant

# %% [markdown]
# ## 2. Inspect column types and completeness
#
# To understand the raw dataset, we check:
#
# - The inferred **data types** of each column (e.g. string, integer, float).
# - How many **non-null values** each column has.
#
# This helps our team see which columns might need cleaning, conversion,
# or imputation later.

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   transaction_id             1200 non-null   int64
#  1   customer_id                1200 non-null   int64
#  2   transaction_datetime       1200 non-null   object
#  3   country                    1200 non-null   object
#  4   channel                    1200 non-null   object
#  5   merchant_category          1150 non-null   object
#  6   amount                     1200 non-null   float64
#  7   device_trust_score         1148 non-null   float64
#  8   num_txn_24h_customer       1200 non-null   int64
#  9   previous_chargeback_count  1200 non-null   int64
#  10  is_fraud                   1200 non-null   int64
#  11  transaction_note           973 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 112.6+ KB

# %%
df_raw.describe(include="all")
# Out:
#         transaction_id  customer_id transaction_datetime country     channel  \
# count      1200.000000  1200.000000                 1200    1200        1200
# unique             NaN          NaN                 1200       8           3
# top                NaN          NaN  2022-04-21T21:41:41      US  mobile_app
# freq               NaN          NaN                    1     212         405
# mean        600.500000  1090.850000                  NaN     NaN         NaN
# std         346.554469    51.657603                  NaN     NaN         NaN
# min           1.000000  1000.000000                  NaN     NaN         NaN
# 25%         300.750000  1046.000000                  NaN     NaN         NaN
# 50%         600.500000  1091.000000                  NaN     NaN         NaN
# 75%         900.250000  1134.000000                  NaN     NaN         NaN
# max        1200.000000  1179.000000                  NaN     NaN         NaN
#
#        merchant_category       amount  device_trust_score  \
# count               1150  1200.000000         1148.000000
# unique                 5          NaN                 NaN
# top               luxury          NaN                 NaN
# freq                 250          NaN                 NaN
# mean                 NaN  2590.959925           52.662021
# std                  NaN  1636.565518           25.400109
# min                  NaN  -189.250000           -5.000000
# 25%                  NaN  1300.060000           30.750000
# 50%                  NaN  2520.040000           52.000000
# 75%                  NaN  3753.340000           74.000000
# max                  NaN  9984.420000          120.000000
#
#         num_txn_24h_customer  previous_chargeback_count     is_fraud  \
# count            1200.000000                1200.000000  1200.000000
# unique                   NaN                        NaN          NaN
# top                      NaN                        NaN          NaN
# freq                     NaN                        NaN          NaN
# mean                3.108333                   1.733333     0.067500
# std                 2.898896                   1.618973     0.250991
# min                 0.000000                   0.000000     0.000000
# 25%                 1.000000                   0.000000     0.000000
# 50%                 3.000000                   2.000000     0.000000
# 75%                 5.000000                   3.000000     0.000000
# max                34.000000                  10.000000     1.000000
#
#        transaction_note
# count               973
# unique                6
# top          new device
# freq                167
# mean                NaN
# std                 NaN
# min                 NaN
# 25%                 NaN
# 50%                 NaN
# 75%                 NaN
# max                 NaN

# %% [markdown]
# ## 3. Data cleaning

# %%
import numpy as np

# %%
df_clean = df_raw.copy()

# %%
df_clean.isna().sum()
# Out:
# transaction_id                 0
# customer_id                    0
# transaction_datetime           0
# country                        0
# channel                        0
# merchant_category             50
# amount                         0
# device_trust_score            52
# num_txn_24h_customer           0
# previous_chargeback_count      0
# is_fraud                       0
# transaction_note             227
# dtype: int64

# %%
# !pip install missingno

# Visualize missing data
import missingno as msno
msno.matrix(df_clean)
# Out:
# Requirement already satisfied: missingno in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.5.2)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from missingno) (2.1.2)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from missingno) (3.9.2)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from missingno) (1.14.1)
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->missingno) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->missingno) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->missingno) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->missingno) (24.1)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->missingno) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->missingno) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn->missingno) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn->missingno) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# <Axes: >

# %% [markdown]
# Data Imputation

# %%
# impute missing device_trust_score with median
median_device_trust_score = df_clean['device_trust_score'].median()
df_clean['device_trust_score'].fillna(median_device_trust_score, inplace=True)
# Out:
# /var/folders/x4/phf6ssbd7wb_067jk3n3l6hc0000gn/T/ipykernel_64496/1469800705.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['device_trust_score'].fillna(median_device_trust_score, inplace=True)

# %%
# impute missing merchant category with mode
mode_merchant_category = df_clean['merchant_category'].mode()[0]
df_clean['merchant_category'].fillna(mode_merchant_category, inplace=True)
# Out:
# /var/folders/x4/phf6ssbd7wb_067jk3n3l6hc0000gn/T/ipykernel_64496/2448250322.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['merchant_category'].fillna(mode_merchant_category, inplace=True)

# %%
df_clean['transaction_note'] = df_clean['transaction_note'].fillna('No transaction note found')

# %% [markdown]
# Data validation

# %%
# Check if there is negative value @ amount
negative_amount = df_clean['amount'] < 0

print("Count of -ve value in amount transaction",(negative_amount).sum())

print("Rows with negative amount (before fix):")
df_clean.loc[negative_amount]
# Out:
# Count of -ve value in amount transaction 6
# Rows with negative amount (before fix):
#       transaction_id  customer_id transaction_datetime country       channel  \
# 266              267         1083  2024-10-09T20:42:03      SG           web
# 686              687         1072  2024-09-08T06:51:17      UK    mobile_app
# 689              690         1052  2024-03-22T02:52:26      JP  pos_terminal
# 1031            1032         1047  2023-05-22T00:07:45      US    mobile_app
# 1038            1039         1093  2022-10-18T02:20:03      MY    mobile_app
# 1139            1140         1039  2022-12-25T08:55:19      US  pos_terminal
#
#      merchant_category  amount  device_trust_score  num_txn_24h_customer  \
# 266             travel  -30.20                29.0                     2
# 686          groceries -130.39                82.0                     3
# 689             travel -186.97                95.0                     5
# 1031            travel -189.25                73.0                     5
# 1038            gaming -185.62                37.0                     0
# 1139            travel -160.53                35.0                     3
#
#       previous_chargeback_count  is_fraud           transaction_note
# 266                           3         0         overnight shipping
# 686                           3         0            high value item
# 689                           2         0  No transaction note found
# 1031                          3         0                 new device
# 1038                          2         0  No transaction note found
# 1139                         10         0         overnight shipping

# %%
# Apply absolute value to -ve amount
df_clean.loc[negative_amount, 'amount'] = df_clean.loc[negative_amount, 'amount'].abs()

print("Rows after applying absolute value:")
df_clean.loc[negative_amount]
# Out:
# Rows after applying absolute value:
#       transaction_id  customer_id transaction_datetime country       channel  \
# 266              267         1083  2024-10-09T20:42:03      SG           web
# 686              687         1072  2024-09-08T06:51:17      UK    mobile_app
# 689              690         1052  2024-03-22T02:52:26      JP  pos_terminal
# 1031            1032         1047  2023-05-22T00:07:45      US    mobile_app
# 1038            1039         1093  2022-10-18T02:20:03      MY    mobile_app
# 1139            1140         1039  2022-12-25T08:55:19      US  pos_terminal
#
#      merchant_category  amount  device_trust_score  num_txn_24h_customer  \
# 266             travel   30.20                29.0                     2
# 686          groceries  130.39                82.0                     3
# 689             travel  186.97                95.0                     5
# 1031            travel  189.25                73.0                     5
# 1038            gaming  185.62                37.0                     0
# 1139            travel  160.53                35.0                     3
#
#       previous_chargeback_count  is_fraud           transaction_note
# 266                           3         0         overnight shipping
# 686                           3         0            high value item
# 689                           2         0  No transaction note found
# 1031                          3         0                 new device
# 1038                          2         0  No transaction note found
# 1139                         10         0         overnight shipping

# %%
# Check if device trust score outside [0,100] 
invalid_score = (df_clean['device_trust_score'] < 0) | (df_clean['device_trust_score'] > 100)
print("Count of invalid device_trust_score range(0-100):", ((invalid_score).sum()))

df_clean.loc[invalid_score]
# Out:
# Count of invalid device_trust_score range(0-100): 6
#      transaction_id  customer_id transaction_datetime country       channel  \
# 45               46         1032  2023-02-25T02:53:48      AU  pos_terminal
# 280             281         1114  2022-02-08T15:09:41      SG           web
# 449             450         1136  2024-11-17T02:10:28      SG    mobile_app
# 479             480         1101  2022-01-16T11:50:14      JP    mobile_app
# 749             750         1169  2023-02-17T20:09:13      JP           web
# 827             828         1151  2023-02-01T22:54:23      AU  pos_terminal
#
#     merchant_category   amount  device_trust_score  num_txn_24h_customer  \
# 45             luxury  1165.76                -5.0                     1
# 280            luxury  3500.58               120.0                     6
# 449            travel  2004.84               120.0                     1
# 479            gaming  4513.46               105.0                     0
# 749         groceries  4745.77               105.0                     1
# 827            luxury   331.02                -5.0                     5
#
#      previous_chargeback_count  is_fraud           transaction_note
# 45                           1         0  No transaction note found
# 280                          3         0  No transaction note found
# 449                          0         0              VPN suspected
# 479                          1         0        first time merchant
# 749                          0         0                 new device
# 827                          2         0              VPN suspected

# %%
# Clip values to the max or min range
df_clean.loc[invalid_score, 'device_trust_score'] = df_clean.loc[invalid_score, 'device_trust_score'].clip(0, 100)

print("Rows after applying absolute value:")
df_clean.loc[invalid_score]
# Out:
# Rows after applying absolute value:
#      transaction_id  customer_id transaction_datetime country       channel  \
# 45               46         1032  2023-02-25T02:53:48      AU  pos_terminal
# 280             281         1114  2022-02-08T15:09:41      SG           web
# 449             450         1136  2024-11-17T02:10:28      SG    mobile_app
# 479             480         1101  2022-01-16T11:50:14      JP    mobile_app
# 749             750         1169  2023-02-17T20:09:13      JP           web
# 827             828         1151  2023-02-01T22:54:23      AU  pos_terminal
#
#     merchant_category   amount  device_trust_score  num_txn_24h_customer  \
# 45             luxury  1165.76                 0.0                     1
# 280            luxury  3500.58               100.0                     6
# 449            travel  2004.84               100.0                     1
# 479            gaming  4513.46               100.0                     0
# 749         groceries  4745.77               100.0                     1
# 827            luxury   331.02                 0.0                     5
#
#      previous_chargeback_count  is_fraud           transaction_note
# 45                           1         0  No transaction note found
# 280                          3         0  No transaction note found
# 449                          0         0              VPN suspected
# 479                          1         0        first time merchant
# 749                          0         0                 new device
# 827                          2         0              VPN suspected

# %%
print(df_clean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   transaction_id             1200 non-null   int64
#  1   customer_id                1200 non-null   int64
#  2   transaction_datetime       1200 non-null   object
#  3   country                    1200 non-null   object
#  4   channel                    1200 non-null   object
#  5   merchant_category          1200 non-null   object
#  6   amount                     1200 non-null   float64
#  7   device_trust_score         1200 non-null   float64
#  8   num_txn_24h_customer       1200 non-null   int64
#  9   previous_chargeback_count  1200 non-null   int64
#  10  is_fraud                   1200 non-null   int64
#  11  transaction_note           1200 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 112.6+ KB
# None

# %%
df_clean.describe(include="all")
# Out:
#         transaction_id  customer_id transaction_datetime country     channel  \
# count      1200.000000  1200.000000                 1200    1200        1200
# unique             NaN          NaN                 1200       8           3
# top                NaN          NaN  2022-04-21T21:41:41      US  mobile_app
# freq               NaN          NaN                    1     212         405
# mean        600.500000  1090.850000                  NaN     NaN         NaN
# std         346.554469    51.657603                  NaN     NaN         NaN
# min           1.000000  1000.000000                  NaN     NaN         NaN
# 25%         300.750000  1046.000000                  NaN     NaN         NaN
# 50%         600.500000  1091.000000                  NaN     NaN         NaN
# 75%         900.250000  1134.000000                  NaN     NaN         NaN
# max        1200.000000  1179.000000                  NaN     NaN         NaN
#
#        merchant_category       amount  device_trust_score  \
# count               1200  1200.000000         1200.000000
# unique                 5          NaN                 NaN
# top               luxury          NaN                 NaN
# freq                 300          NaN                 NaN
# mean                 NaN  2592.431525           52.600000
# std                  NaN  1634.231457           24.731013
# min                  NaN     4.600000            0.000000
# 25%                  NaN  1300.060000           31.000000
# 50%                  NaN  2520.040000           52.000000
# 75%                  NaN  3753.340000           74.000000
# max                  NaN  9984.420000          100.000000
#
#         num_txn_24h_customer  previous_chargeback_count     is_fraud  \
# count            1200.000000                1200.000000  1200.000000
# unique                   NaN                        NaN          NaN
# top                      NaN                        NaN          NaN
# freq                     NaN                        NaN          NaN
# mean                3.108333                   1.733333     0.067500
# std                 2.898896                   1.618973     0.250991
# min                 0.000000                   0.000000     0.000000
# 25%                 1.000000                   0.000000     0.000000
# 50%                 3.000000                   2.000000     0.000000
# 75%                 5.000000                   3.000000     0.000000
# max                34.000000                  10.000000     1.000000
#
#                  transaction_note
# count                        1200
# unique                          7
# top     No transaction note found
# freq                          227
# mean                          NaN
# std                           NaN
# min                           NaN
# 25%                           NaN
# 50%                           NaN
# 75%                           NaN
# max                           NaN

# %%
df_clean.to_csv("../data/processed/cleaned_dataset.csv", index=False)
